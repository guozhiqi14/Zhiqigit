# %% [markdown]
# ** Note that NYC's homicide counts are constantly smaller than UCR report.**
#
# ** Also, since we have two separate dataset, one is for 2005-2016 and one is for first queater in 2017, we have count incidents in 2017 (reported in 2017 but happened in 2016, and then add those numbers to 2016's counting.**

# %%
import pandas as pd
from dateutil import parser

# %%
nyc = pd.read_csv('/Volumes/TRANSCEND/Violence Tracker/NYC/NYPD_Crimes_2006-2015.csv')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nyc.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD          float64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# PARKS_NM              object
# HADEVELOPT            object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# dtype: object

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC              ...               ADDR_PCT_CD  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO              ...                      44.0
# ...

# %%
'''
Note: it's gonna take a while to convert string to datetime for this 'large' dataframe, around 15min
'''
nyc['CMPLNT_FR_DT'] = pd.to_datetime(nyc['CMPLNT_FR_DT'],errors='coerce')

# %%
nyc.CMPLNT_FR_DT.dt.year.unique()
# Out:
# array([ 2015.,  2013.,  2009.,  2014.,  2011.,  2004.,  2012.,  1992.,
#         1969.,  2010.,  1979.,  2008.,  2006.,  2007.,  2005.,  2001.,
#         1982.,    nan,  1995.,  1993.,  1965.,  2000.,  2002.,  1990.,
#         1999.,  1996.,  2003.,  1987.,  1975.,  1989.,  1915.,  1986.,
#         1981.,  1950.,  1998.,  1978.,  1997.,  1910.,  1991.,  1955.,
#         1914.,  1958.,  1994.,  1974.,  1977.,  1980.,  1930.,  1988.,
#         1913.,  1941.,  1945.,  1954.,  1971.,  1973.,  1985.,  1912.,
#         1972.,  1984.,  1942.,  1983.,  1920.,  1968.,  1938.,  1911.,
#         1970.,  1959.,  1909.,  1960.,  1940.,  1900.,  1929.,  1976.,
#         1919.,  1908.,  1948.,  1967.,  1962.,  1966.,  1956.,  1922.,
#         1906.,  1946.,  1961.,  1905.,  1964.,  2016.,  1916.])

# %%
nyc['Year'], nyc['Month'] = nyc['CMPLNT_FR_DT'].dt.year, nyc['CMPLNT_FR_DT'].dt.month

# %%
'''
NYC's data from year 2014-2016
'''
nyc_14_16 = nyc[nyc['Year'] >= 2014]

# %%
nyc.OFNS_DESC.unique()
# Out:
# array(['FORGERY', 'MURDER & NON-NEGL. MANSLAUGHTER', 'DANGEROUS DRUGS',
#        'ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT',
#        'DANGEROUS WEAPONS', 'PETIT LARCENY', 'GRAND LARCENY', 'ROBBERY',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'CRIMINAL MISCHIEF & RELATED OF',
#        'RAPE', 'INTOXICATED & IMPAIRED DRIVING', 'HARRASSMENT 2',
#        'SEX CRIMES', 'BURGLARY', 'CRIMINAL TRESPASS',
#        'MISCELLANEOUS PENAL LAW', 'VEHICLE AND TRAFFIC LAWS',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'FRAUDS',
#        'GRAND LARCENY OF MOTOR VEHICLE', 'OFFENSES INVOLVING FRAUD',
#        'OFFENSES AGAINST THE PERSON', 'FRAUDULENT ACCOSTING',
#        'OTHER OFFENSES RELATED TO THEF', 'GAMBLING', 'ARSON',
#        'POSSESSION OF STOLEN PROPERTY', 'UNAUTHORIZED USE OF A VEHICLE',
#        'THEFT-FRAUD', 'DISORDERLY CONDUCT', nan, 'ADMINISTRATIVE CODE',
#        'CHILD ABANDONMENT/NON SUPPORT', 'OTHER STATE LAWS (NON PENAL LA',
# ...

# %%
'''
Here we only count 'MURDER & NON-NEGL. MANSLAUGHTER' type 
Neg-Vehicle and HOMICIDE-NEGLIGENT does not included.
'''
#murder = ['MURDER & NON-NEGL. MANSLAUGHTER', 'HOMICIDE-NEGLIGENT-VEHICLE','HOMICIDE-NEGLIGENT,UNCLASSIFIE']
murder = ['MURDER & NON-NEGL. MANSLAUGHTER']
flag = nyc_14_16.OFNS_DESC.isin(murder)
nyc_count = nyc_14_16[flag].groupby(['Year','Month','OFNS_DESC']).size().reset_index(name='count')

# %%
nyc_count.insert(0,'City','New York City')
nyc_count.insert(1,'State','NY')
nyc_count['UCR_Type'] = ''
nyc_count = nyc_count.rename(columns = {'OFNS_DESC':'homicide_type'})

# %% [markdown]
# Note that in 2017's dataset, there might be situations that crime report date is in 2017 but occurred date is in 2016, thus we need to add those number from 17's dataset.

# %%
'''
Additional homicides counts from 2017's dataset (occurred in 2016 but reported in 2017) 
'''
addition_homi_for_16 = pd.read_csv("addition_homi_for_16.csv")

# %%
addition_homi_for_16
# Out:
#             City State    Year  Month                    homicide_type  count  \
# 0  New York City    NY  2016.0    6.0  MURDER & NON-NEGL. MANSLAUGHTER      1
# 1  New York City    NY  2016.0    8.0  MURDER & NON-NEGL. MANSLAUGHTER      1
# 2  New York City    NY  2016.0   10.0  MURDER & NON-NEGL. MANSLAUGHTER      3
# 3  New York City    NY  2016.0   11.0  MURDER & NON-NEGL. MANSLAUGHTER      2
#
#    UCR_Type
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN

# %%
nyc_count
# Out:
#              City State    Year  Month                    homicide_type  \
# 0   New York City    NY  2014.0    1.0  MURDER & NON-NEGL. MANSLAUGHTER
# 1   New York City    NY  2014.0    2.0  MURDER & NON-NEGL. MANSLAUGHTER
# 2   New York City    NY  2014.0    3.0  MURDER & NON-NEGL. MANSLAUGHTER
# 3   New York City    NY  2014.0    4.0  MURDER & NON-NEGL. MANSLAUGHTER
# 4   New York City    NY  2014.0    5.0  MURDER & NON-NEGL. MANSLAUGHTER
# 5   New York City    NY  2014.0    6.0  MURDER & NON-NEGL. MANSLAUGHTER
# 6   New York City    NY  2014.0    7.0  MURDER & NON-NEGL. MANSLAUGHTER
# 7   New York City    NY  2014.0    8.0  MURDER & NON-NEGL. MANSLAUGHTER
# 8   New York City    NY  2014.0    9.0  MURDER & NON-NEGL. MANSLAUGHTER
# 9   New York City    NY  2014.0   10.0  MURDER & NON-NEGL. MANSLAUGHTER
# 10  New York City    NY  2014.0   11.0  MURDER & NON-NEGL. MANSLAUGHTER
# 11  New York City    NY  2014.0   12.0  MURDER & NON-NEGL. MANSLAUGHTER
# ...

# %%
'''
Add homicide incidents which recorded in 2017's dataset
'''
nyc_count = pd.concat([nyc_count,addition_homi_for_16]).\
groupby(['City','State','Year','Month','homicide_type']).sum().reset_index()

# %%
nyc_14_count = nyc_count[nyc_count.Year==2014]['count'].sum()
nyc_15_count = nyc_count[nyc_count.Year==2015]['count'].sum()
nyc_16_count = nyc_count[nyc_count.Year==2016]['count'].sum()

print('Year 2014 homicide count',nyc_14_count )
print('Year 2015 homicide count',nyc_15_count )
print('Year 2016 homicide count',nyc_16_count )
# Out:
# Year 2014 homicide count 331
# Year 2015 homicide count 344
# Year 2016 homicide count 321

# %% [markdown]
# Note that the result is constantly smaller than the offical UCR report for year 2014 and year 2015. UCR has homicide count **333** for 2014 and **352** for 2015. Please refer to NYPD's official published report checking for consistency.
#
# [NYPD Report link](http://www1.nyc.gov/assets/nypd/downloads/pdf/analysis_and_planning/seven-major-felony-offenses-2000-2016.pdf)

# %%
nyc_count
# Out:
#              City State    Year  Month                    homicide_type  \
# 0   New York City    NY  2014.0    1.0  MURDER & NON-NEGL. MANSLAUGHTER
# 1   New York City    NY  2014.0    2.0  MURDER & NON-NEGL. MANSLAUGHTER
# 2   New York City    NY  2014.0    3.0  MURDER & NON-NEGL. MANSLAUGHTER
# 3   New York City    NY  2014.0    4.0  MURDER & NON-NEGL. MANSLAUGHTER
# 4   New York City    NY  2014.0    5.0  MURDER & NON-NEGL. MANSLAUGHTER
# 5   New York City    NY  2014.0    6.0  MURDER & NON-NEGL. MANSLAUGHTER
# 6   New York City    NY  2014.0    7.0  MURDER & NON-NEGL. MANSLAUGHTER
# 7   New York City    NY  2014.0    8.0  MURDER & NON-NEGL. MANSLAUGHTER
# 8   New York City    NY  2014.0    9.0  MURDER & NON-NEGL. MANSLAUGHTER
# 9   New York City    NY  2014.0   10.0  MURDER & NON-NEGL. MANSLAUGHTER
# 10  New York City    NY  2014.0   11.0  MURDER & NON-NEGL. MANSLAUGHTER
# 11  New York City    NY  2014.0   12.0  MURDER & NON-NEGL. MANSLAUGHTER
# ...

# %%
nyc_count.to_csv('NYC_NYPD_homicide_counts_2014_2016.csv',index=False,encoding='utf-8')
