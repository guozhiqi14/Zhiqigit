# %%
import numpy as np
import pandas as pd

# %%
homicide_types = ['MURDER','HOMICIDE','DISCHARGE FIREARMS/SHOTS FIRED','SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT','SHOTS FIRED AT INHABITED DWELLING','ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT','WEAPONS POSSESSION/BOMBING','CRIMINAL HOMICIDE','MANSLAUGHTER, NEGLIGENT','LYNCHING - ATTEMPTED','LYNCHING']

# %%
df=pd.read_csv('data/Crime_Data_From_2010_to_Present.csv')

# %%
df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID   Area Name  \
# 0  100220871    11/13/2010    11/12/2010         1200.0      2.0     Rampart
# 1  100416450    10/14/2010    10/14/2010         1200.0      4.0  Hollenbeck
# 2  100506372    02/17/2010    02/09/2010         1600.0      5.0      Harbor
# 3  100516503    08/31/2010    08/30/2010         2300.0      5.0      Harbor
# 4  100516679    09/05/2010    09/04/2010         1330.0      5.0      Harbor
#
#    Reporting District  Crime Code   Crime Code Desc MO Codes  \
# 0               271.0       510.0  VEHICLE - STOLEN      NaN
# 1               422.0       510.0  VEHICLE - STOLEN      NaN
# 2               563.0       510.0  VEHICLE - STOLEN      NaN
# 3               562.0       510.0  VEHICLE - STOLEN      NaN
# 4               506.0       510.0  VEHICLE - STOLEN      NaN
#
#            ...           Weapon Desc Status Code  Status Desc  Crm Cd 1  \
# ...

# %%
df.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Desc', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Desc', 'Weapon Used Cd',
#        'Weapon Desc', 'Status Code', 'Status Desc', 'Crm Cd 1', 'Crm Cd 2',
#        'Crm Cd 3', 'Crm Cd 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
df['Date Occurred'].isnull().sum()
# Out:
# 25954

# %%
df['Date Occurred'].notnull().sum()
# Out:
# 1486928

# %%
df[df['Date Reported'].isnull()]
# Out:
#          DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 1442925  170209347           NaN           NaN            NaN      NaN
# 1442947  170100805           NaN           NaN            NaN      NaN
# 1442953  170100806           NaN           NaN            NaN      NaN
# 1442961  170100809           NaN           NaN            NaN      NaN
# 1442965  170100810           NaN           NaN            NaN      NaN
# 1442974  170100811           NaN           NaN            NaN      NaN
# 1442976  170111377           NaN           NaN            NaN      NaN
# 1443041  170208943           NaN           NaN            NaN      NaN
# 1443108  170209420           NaN           NaN            NaN      NaN
# 1443122  170100812           NaN           NaN            NaN      NaN
# 1443207  170100814           NaN           NaN            NaN      NaN
# 1443228  170100815           NaN           NaN            NaN      NaN
# ...

# %%
df2=df.loc[df['Date Occurred'].str.endswith('2014',na=False)]

# %%
df['year'] = pd.DatetimeIndex(df['Date Occurred']).year
df['month']=pd.DatetimeIndex(df['Date Occurred']).month

# %%
df.to_csv('data/LAPD1.csv',index = False, encoding = 'utf-8')

# %%
df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID   Area Name  \
# 0  100220871    11/13/2010    11/12/2010         1200.0      2.0     Rampart
# 1  100416450    10/14/2010    10/14/2010         1200.0      4.0  Hollenbeck
# 2  100506372    02/17/2010    02/09/2010         1600.0      5.0      Harbor
# 3  100516503    08/31/2010    08/30/2010         2300.0      5.0      Harbor
# 4  100516679    09/05/2010    09/04/2010         1330.0      5.0      Harbor
#
#    Reporting District  Crime Code   Crime Code Desc MO Codes  ...    \
# 0               271.0       510.0  VEHICLE - STOLEN      NaN  ...
# 1               422.0       510.0  VEHICLE - STOLEN      NaN  ...
# 2               563.0       510.0  VEHICLE - STOLEN      NaN  ...
# 3               562.0       510.0  VEHICLE - STOLEN      NaN  ...
# 4               506.0       510.0  VEHICLE - STOLEN      NaN  ...
#
#    Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4       Address  \
# ...

# %%
df.loc[(df['year']==2014) & (df['month']==1) & df['Crime Code Desc'].isin(homicide_types)]

# %%
df2 = df.loc[(df['year']==2014) & df['Crime Code Desc'].isin(homicide_types)]

# %%
df.groupby(['year','month','Crime Code Desc']).count()
# Out:
#                                                                  DR Number  \
# year   month Crime Code Desc
# 2010.0 1.0   ARSON                                                      33
#              ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER                9
#              ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT            720
#              ATTEMPTED ROBBERY                                         131
#              BATTERY - SIMPLE ASSAULT                                 1689
#              BATTERY ON A FIREFIGHTER                                    1
#              BATTERY POLICE (SIMPLE)                                    34
#              BATTERY WITH SEXUAL CONTACT                               106
#              BIKE - STOLEN                                              14
#              BOAT - STOLEN                                               2
#              BOMB SCARE                                                 11
# ...

# %%
df3 = df.groupby( [ 'year','month','Crime Code Desc'] ).size().reset_index(name='count')
# Out:
#         year  month                                    Crime Code Desc  count
# 0     2010.0    1.0                                              ARSON     33
# 1     2010.0    1.0       ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER      9
# 2     2010.0    1.0     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    720
# 3     2010.0    1.0                                  ATTEMPTED ROBBERY    131
# 4     2010.0    1.0                           BATTERY - SIMPLE ASSAULT   1689
# 5     2010.0    1.0                           BATTERY ON A FIREFIGHTER      1
# 6     2010.0    1.0                            BATTERY POLICE (SIMPLE)     34
# 7     2010.0    1.0                        BATTERY WITH SEXUAL CONTACT    106
# 8     2010.0    1.0                                      BIKE - STOLEN     14
# 9     2010.0    1.0                                      BOAT - STOLEN      2
# 10    2010.0    1.0                                         BOMB SCARE     11
# ...

# %%
df3.loc[(df3['year']>2013) & df3['Crime Code Desc'].isin(homicide_types)]
# Out:
#         year  month                                   Crime Code Desc  count
# 4820  2014.0    1.0    ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    525
# 4850  2014.0    1.0                                 CRIMINAL HOMICIDE     15
# 4855  2014.0    1.0                    DISCHARGE FIREARMS/SHOTS FIRED     28
# 4894  2014.0    1.0                 SHOTS FIRED AT INHABITED DWELLING     17
# 4895  2014.0    1.0  SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT      2
# 4923  2014.0    2.0    ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    519
# 4949  2014.0    2.0                                 CRIMINAL HOMICIDE     15
# 4954  2014.0    2.0                    DISCHARGE FIREARMS/SHOTS FIRED     18
# 4993  2014.0    2.0                 SHOTS FIRED AT INHABITED DWELLING     15
# 4994  2014.0    2.0  SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT      1
# 5020  2014.0    2.0                        WEAPONS POSSESSION/BOMBING      2
# ...

# %%
df3.loc[(df3['year']>2013) & df3['Crime Code Desc'].isin(homicide_types)].to_csv('data/LA_homicide_counts.csv',index = False, encoding = 'utf-8')
